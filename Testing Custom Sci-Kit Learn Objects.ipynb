# %%
#Importing Dependencies
import requests
import bs4
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import csv

#Importing Sci-kit + Stats Models Dependencies
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold, cross_val_score

#Models
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.naive_bayes import MultinomialNB, ComplementNB

#GridSearch
from sklearn.model_selection import GridSearchCV

#Pre-processing
from sklearn.preprocessing import StandardScaler

#Scipy Integration for Sparse Matrixes
from scipy import sparse

#Plotting & Visualisation Metrics
from matplotlib import pyplot as plt
import seaborn as sns

#Scoring & Evaluation Metrics
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, precision_score, f1_score
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score

#Pipelines
from sklearn.pipeline import Pipeline

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class Cleaner(BaseEstimator, TransformerMixin):
    
    def __init__(self, X, salary_column= None, cols_to_drop = None, columns_to_dummify= None):
        self.salary_column = salary_column
        self.salary_median = X[self.salary_column].median()
        self.cols_to_drop = cols_to_drop
        self.columns_to_dummify= columns_to_dummify
        self.X = X
    
    
    #Creating The Salary Class 
    def salary_class(self):
        data = ['HIGH SALARY' if item > self.salary_median else 'LOW SALARY' for item in self.X['Salaries($)']]
        return data
    

    #Creating The States + Locations Features
    def state_and_locations(self):
        states = [str(item).split()[-1] for item in self.X['Locations']]
        locations = [(" ".join(str(item).split()[:-1])).replace(',','') for item in cleaned_df['Locations']]   
        return states, locations
    
    
    def dropping_cols(self):
        return self.X.drop(columns= self.cols_to_drop, inplace=True)
    
    
    def make_dummy_cols(self):
        for column in self.columns_to_dummify:
            try:
                categories = np.sort(self.X[column].unique())
                for category in categories[1:]:
                    self.X[column+'_'+str(category)] = self.X[column].map(
                        lambda x: 1 if x == category else 0)
                self.X = self.X.drop(column, axis=1)
            except:
                pass
        return self.X
    
    
    def transform(self, *args):
        #Cleaning & Adding Features.
        self.X['Salary_Class'] = self.salary_class()
        self.X['State'] = self.state_and_locations()[0]
        self.X['Locations'] = self.state_and_locations()[1]
        
        #Dropping Columns.
        self.dropping_cols()
        
        #Dropping NA Values.
        self.X.dropna(how='any', inplace=True)
        
        #Dummfying The Data
        self.make_dummy_cols()
        return self.X
     
        
    def fit(self, *args):
        pass

# %%
# Create a TFID_Vectorizer Helper Class For The Pipeline!

from sklearn.feature_extraction.text import TfidfVectorizer

class TFID_Vectorizer(BaseEstimator, TransformerMixin):
    
    def __init__(self, X, cols_to_vectorize = None):
        self.cols_to_vectorize = cols_to_vectorize   
        self.tvec = TfidfVectorizer(stop_words='english')
        self.original_sparse = None
        
        
    def fit(self, X, y=None, *args):
        self.tvec = self.tvec.fit(X[self.cols_to_vectorize])
        self.new_data = X[X.columns.difference(['Titles'])]
        return self.tvec
 

    def transform(self, X, y=None, *args):
        if isinstance(X, pd.DataFrame):            
            Additional_Data = X[X.columns.difference(['Titles'])]
            Sparse_Original_Data = sparse.csr_matrix(Additional_Data.values)
            Y = self.tvec.transform(X[self.cols_to_vectorize])
            X = sparse.hstack([Y, Sparse_Original_Data])
            return X
            
        else:    
            print('test')

# %%
cleaned_df = pd.read_csv("exported_dataframe.csv")
Clean_mod = Cleaner(salary_column='Salaries($)', X = cleaned_df, cols_to_drop=['Companies', 'Salaries($)']
                   , columns_to_dummify = ['State', 'Locations'] )
X = Clean_mod.transform()
y = X.pop('Salary_Class')

# %%
cleaned_df
# Out:
#                                                 Titles        Locations  \
# 152                  MTC Technical Architect-Data & AI          Chicago
# 153                   Management Operations Analyst II      Cook County
# 154                                     Data Scientist          Chicago
# 155        Research Analyst - Oakton Community College      Des Plaines
# 156                              Data Science Educator          Boulder
# 157  Computer Scientist, ZP-1550-II (GS-7/10 equiva...          Boulder
# 158                    Data Scientist - Bioinformatics           Denver
# 160                                     Data Scientist           Denver
# 161                   Chemistry Program Manager - 2040           Denver
# 162                 UX Copywriter / Content Strategist           Denver
# 163  Imagery Science Services-Journeyman-TS/SCI wit...           Denver
# 164                          Data Analytics Specialist        Manhattan
# 165                                  Data Analyst, PNA        Manhattan
# 166      Burial Desk Clerk, Bureau of Vital Statistics        Manhattan
# 167  Associate Underwriter, Data Analysis Rating Te...         New York
# 169         City Research Scientist, Bluebelt Planning         New York
# 170                                 Sr. Data Scientist         New York
# 172                         GENERAL PHYSICAL SCIENTIST          Phoenix
# 173                                      MATHEMATICIAN          Phoenix
# 174                   RESEARCH AND STATISTICAL ANALYST          Phoenix
# 175  Law Research Fellow in Artificial Intelligence...          Phoenix
# 176                                OPERATIONS RESEARCH          Phoenix
# 177                       Planning Research Analyst Sr  Maricopa County
# 178                                          Physicist          Phoenix
# 180          Computational Mechanics Software Engineer       Scottsdale
# 181                         Engineering Data Scientist     Philadelphia
# 182  Business Development Specialist (Market Resear...         Voorhees
# 185                             Sr. Research Scientist            Miami
# 186      Senior Embedded Software Engineer, Controller  Fort Lauderdale
# 187          Program Manager - Data Science and Design          Seattle
# ..                                                 ...              ...
# 493               Data Scientist - Operations Research            Tempe
# 494               Data Scientist - Predictive Modeling            Tempe
# 495                        Civil Engineer (Structural)     Philadelphia
# 497  Data Analyst (One Year Grant Funded - Maybe ex...     Philadelphia
# 500        AI and Analytics Research Software Engineer          Seattle
# 501         Director of Model Development – IA Channel          Seattle
# 504                    CODING SPECIALIST 3 - PATHOLOGY          Seattle
# 506  Manager, Software Development (Woot LLC, Seatt...          Seattle
# 507                                     Data Scientist      Los Angeles
# 508                                       STATISTICIAN
# 511  Senior Software Engineer, Performance - Contra...      Culver City
# 515                            Senior Academic Advisor         Columbus
# 516         Investment Analyst-Quantitative Management         Columbus
# 517                                 Senior AI Engineer           Novato
# 518  Senior Software Engineer in Test - Machine Lea...    San Francisco
# 519  Technology Expert I-Epic Beacon/Research Busin...    San Francisco
# 521    Student Services Advisor 3 Job - Fung Institute         Berkeley
# 522           Senior Software Engineer - Data Platform    San Francisco
# 523  Senior Software Engineer - Communication Safet...        San Mateo
# 524     Data Scientist - Principal - San Francisco, CA    San Francisco
# 525         Research Engineering/Scientist Associate I           Austin
# 526                                Health Physicist II           Austin
# 528                        Data Science Manager (Lead)           Austin
# 532                                Research Technician       Pittsburgh
# 533                                Senior Statistician       Pittsburgh
# 536                                 Front End Engineer          Houston
# 538         Senior Research Subject Protection Analyst          Houston
# 540                Statistician (Health) (Direct Hire)          Atlanta
# 542           DPS - LES - Forensic Scientist I-III DNA          Garland
# 543                                  VP Data Scientist          Coppell
#
#      Ratings Salary_Class State  State_CA  State_CO  State_DE  State_FL  \
# 152     87.0  HIGH SALARY    IL         0         0         0         0
# 153     73.0   LOW SALARY    IL         0         0         0         0
# 154     65.0  HIGH SALARY    IL         0         0         0         0
# 155     89.0   LOW SALARY    IL         0         0         0         0
# 156     73.0   LOW SALARY    CO         0         1         0         0
# 157     87.0   LOW SALARY    CO         0         1         0         0
# 158     71.0  HIGH SALARY    CO         0         1         0         0
# 160     73.0  HIGH SALARY    CO         0         1         0         0
# 161     70.0  HIGH SALARY    CO         0         1         0         0
# 162     72.0   LOW SALARY    CO         0         1         0         0
# 163     72.0   LOW SALARY    CO         0         1         0         0
# 164     87.0   LOW SALARY    NY         0         0         0         0
# 165     73.0   LOW SALARY    NY         0         0         0         0
# 166     85.0   LOW SALARY    NY         0         0         0         0
# 167     71.0   LOW SALARY    NY         0         0         0         0
# 169     73.0   LOW SALARY    NY         0         0         0         0
# 170     66.0  HIGH SALARY    NY         0         0         0         0
# 172     88.0   LOW SALARY    AZ         0         0         0         0
# 173     88.0   LOW SALARY    AZ         0         0         0         0
# 174     85.0   LOW SALARY    AZ         0         0         0         0
# 175     88.0   LOW SALARY    AZ         0         0         0         0
# 176     88.0   LOW SALARY    AZ         0         0         0         0
# 177     74.0   LOW SALARY    AZ         0         0         0         0
# 178     88.0   LOW SALARY    AZ         0         0         0         0
# 180     88.0   LOW SALARY    AZ         0         0         0         0
# 181     70.0  HIGH SALARY    PA         0         0         0         0
# 182     70.0   LOW SALARY    NJ         0         0         0         0
# 185     88.0   LOW SALARY    FL         0         0         0         1
# 186     69.0  HIGH SALARY    FL         0         0         0         1
# 187     88.0  HIGH SALARY    WA         0         0         0         0
# ..       ...          ...   ...       ...       ...       ...       ...
# 493     52.0   LOW SALARY    AZ         0         0         0         0
# 494     52.0  HIGH SALARY    AZ         0         0         0         0
# 495     89.0   LOW SALARY    PA         0         0         0         0
# 497     71.0   LOW SALARY    PA         0         0         0         0
# 500     88.0  HIGH SALARY    WA         0         0         0         0
# 501     71.0  HIGH SALARY    WA         0         0         0         0
# 504     86.0   LOW SALARY    WA         0         0         0         0
# 506     51.0  HIGH SALARY    WA         0         0         0         0
# 507     73.0  HIGH SALARY    CA         1         0         0         0
# 508     65.0  HIGH SALARY   nan         0         0         0         0
# 511     69.0  HIGH SALARY    CA         1         0         0         0
# 515     87.0   LOW SALARY    OH         0         0         0         0
# 516     65.0   LOW SALARY    OH         0         0         0         0
# 517     72.0  HIGH SALARY    CA         1         0         0         0
# 518     87.0  HIGH SALARY    CA         1         0         0         0
# 519     86.0  HIGH SALARY    CA         1         0         0         0
# 521     87.0   LOW SALARY    CA         1         0         0         0
# 522     88.0  HIGH SALARY    CA         1         0         0         0
# 523     89.0  HIGH SALARY    CA         1         0         0         0
# 524     70.0  HIGH SALARY    CA         1         0         0         0
# 525     88.0   LOW SALARY    TX         0         0         0         0
# 526     69.0   LOW SALARY    TX         0         0         0         0
# 528     89.0  HIGH SALARY    TX         0         0         0         0
# 532     87.0   LOW SALARY    PA         0         0         0         0
# 533     87.0   LOW SALARY    PA         0         0         0         0
# 536     71.0  HIGH SALARY    TX         0         0         0         0
# 538     74.0   LOW SALARY    TX         0         0         0         0
# 540     87.0   LOW SALARY    GA         0         0         0         0
# 542     73.0   LOW SALARY    TX         0         0         0         0
# 543     68.0  HIGH SALARY    TX         0         0         0         0
#
#      State_GA  State_IL  State_NJ  State_NY  State_OH  State_OR  State_PA  \
# 152         0         1         0         0         0         0         0
# 153         0         1         0         0         0         0         0
# 154         0         1         0         0         0         0         0
# 155         0         1         0         0         0         0         0
# 156         0         0         0         0         0         0         0
# 157         0         0         0         0         0         0         0
# 158         0         0         0         0         0         0         0
# 160         0         0         0         0         0         0         0
# 161         0         0         0         0         0         0         0
# 162         0         0         0         0         0         0         0
# 163         0         0         0         0         0         0         0
# 164         0         0         0         1         0         0         0
# 165         0         0         0         1         0         0         0
# 166         0         0         0         1         0         0         0
# 167         0         0         0         1         0         0         0
# 169         0         0         0         1         0         0         0
# 170         0         0         0         1         0         0         0
# 172         0         0         0         0         0         0         0
# 173         0         0         0         0         0         0         0
# 174         0         0         0         0         0         0         0
# 175         0         0         0         0         0         0         0
# 176         0         0         0         0         0         0         0
# 177         0         0         0         0         0         0         0
# 178         0         0         0         0         0         0         0
# 180         0         0         0         0         0         0         0
# 181         0         0         0         0         0         0         1
# 182         0         0         1         0         0         0         0
# 185         0         0         0         0         0         0         0
# 186         0         0         0         0         0         0         0
# 187         0         0         0         0         0         0         0
# ..        ...       ...       ...       ...       ...       ...       ...
# 493         0         0         0         0         0         0         0
# 494         0         0         0         0         0         0         0
# 495         0         0         0         0         0         0         1
# 497         0         0         0         0         0         0         1
# 500         0         0         0         0         0         0         0
# 501         0         0         0         0         0         0         0
# 504         0         0         0         0         0         0         0
# 506         0         0         0         0         0         0         0
# 507         0         0         0         0         0         0         0
# 508         0         0         0         0         0         0         0
# 511         0         0         0         0         0         0         0
# 515         0         0         0         0         1         0         0
# 516         0         0         0         0         1         0         0
# 517         0         0         0         0         0         0         0
# 518         0         0         0         0         0         0         0
# 519         0         0         0         0         0         0         0
# 521         0         0         0         0         0         0         0
# 522         0         0         0         0         0         0         0
# 523         0         0         0         0         0         0         0
# 524         0         0         0         0         0         0         0
# 525         0         0         0         0         0         0         0
# 526         0         0         0         0         0         0         0
# 528         0         0         0         0         0         0         0
# 532         0         0         0         0         0         0         1
# 533         0         0         0         0         0         0         1
# 536         0         0         0         0         0         0         0
# 538         0         0         0         0         0         0         0
# 540         1         0         0         0         0         0         0
# 542         0         0         0         0         0         0         0
# 543         0         0         0         0         0         0         0
#
#      State_TX  State_WA  State_nan
# 152         0         0          0
# 153         0         0          0
# 154         0         0          0
# 155         0         0          0
# 156         0         0          0
# 157         0         0          0
# 158         0         0          0
# 160         0         0          0
# 161         0         0          0
# 162         0         0          0
# 163         0         0          0
# 164         0         0          0
# 165         0         0          0
# 166         0         0          0
# 167         0         0          0
# 169         0         0          0
# 170         0         0          0
# 172         0         0          0
# 173         0         0          0
# 174         0         0          0
# 175         0         0          0
# 176         0         0          0
# 177         0         0          0
# 178         0         0          0
# 180         0         0          0
# 181         0         0          0
# 182         0         0          0
# 185         0         0          0
# 186         0         0          0
# 187         0         1          0
# ..        ...       ...        ...
# 493         0         0          0
# 494         0         0          0
# 495         0         0          0
# 497         0         0          0
# 500         0         1          0
# 501         0         1          0
# 504         0         1          0
# 506         0         1          0
# 507         0         0          0
# 508         0         0          1
# 511         0         0          0
# 515         0         0          0
# 516         0         0          0
# 517         0         0          0
# 518         0         0          0
# 519         0         0          0
# 521         0         0          0
# 522         0         0          0
# 523         0         0          0
# 524         0         0          0
# 525         1         0          0
# 526         1         0          0
# 528         1         0          0
# 532         0         0          0
# 533         0         0          0
# 536         1         0          0
# 538         1         0          0
# 540         0         0          0
# 542         1         0          0
# 543         1         0          0
#
# [288 rows x 19 columns]

# %%
#Performing A Train Test Split.

X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size=0.2, random_state=1, stratify=y)

# %%
testing = TFID_Vectorizer(X, cols_to_vectorize='Titles')

# %%
testing.fit(X_test)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %% [markdown]
# X_test Data Shape
#
# - Sparse Original Shape: 58 rows ,86 columns
# - Job Titles Original Shape: 58 rows, 304 columns
# - New Sparse Matrix Shape: 58 rows, 390 columns

# %%
testing.transform(X_test)
# Out:
# <58x219 sparse matrix of type '<class 'numpy.float64'>'
# 	with 414 stored elements in COOrdinate format>

# %%
#Creating The Pipeline

pipe = Pipeline(memory=None,
         steps=[('TFID_Vectorizing', testing,
                ('LogisticRegression', LogisticRegressionCV())] verbose=False)
# Out:
#   File "<ipython-input-40-3879ebf30003>", line 5
#     ('LogisticRegression', LogisticRegressionCV())] verbose=False)
#                                                   ^
# SyntaxError: invalid syntax

# %%
a = sparse.csr_matrix(X_train[X_train.columns.difference(['Titles'])])

# %%
a.shape
# Out:
# (230, 86)

# %%
(sparse.hstack([a, a])).shape
# Out:
# (460, 86)
